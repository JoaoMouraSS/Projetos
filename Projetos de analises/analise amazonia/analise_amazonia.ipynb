# %% [markdown]
# # Analise do desmatamento da amazonia.
#
# Analise dos anos de 2004 até o ano de 2019
#
# Uma observação importante é que a Amazônia Legal é uma área que engloba nove estados do Brasil pertencentes à bacia Amazônica, instituido pelo governo federal via lei 1 806/1953, reunindo regiões de idênticas características, com o intuito de melhor planejar o desenvolvimento socio-econômico da região amazônica.

# %% [markdown]
# # Importanto e instalando bibliotecas

# %%
#Processamento dos dados básicos
import pandas as pd

#Construir gráficos
# !pip install -U plotly
import plotly.express as plt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 15.2 MB 4.7 MB/s
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.5.0
#     Uninstalling plotly-5.5.0:
#       Successfully uninstalled plotly-5.5.0
# ...

# %% [markdown]
# # Analisando os dados

# %%
area_desmatada = pd.read_csv('def_area_2004_2019.csv')
inep_brasil = pd.read_csv('inpe_brazilian_amazon_fires_1999_2019.csv')

# %%
fig1 = plt.line(data_frame=area_desmatada, y='AMZ LEGAL', x='Ano/Estados', title= "Diminuição do desmatamento da amazonia legal, mas com um leve aumento apartir de 2014.",markers=True)
fig1.update_layout(xaxis_title='Ano',yaxis_title='Área desmatada')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
area_desmatada.rename(columns={'Ano/Estados':'Ano'}, inplace=True)
area_desmatada
# Out:
#      Ano   AC    AM   AP    MA     MT    PA    RO   RR   TO  AMZ LEGAL
# 0   2004  728  1232   46   755  11814  8870  3858  311  158      27772
# 1   2005  592   775   33   922   7145  5899  3244  133  271      19014
# 2   2006  398   788   30   674   4333  5659  2049  231  124      14286
# 3   2007  184   610   39   631   2678  5526  1611  309   63      11651
# 4   2008  254   604  100  1271   3258  5607  1136  574  107      12911
# 5   2009  167   405   70   828   1049  4281   482  121   61       7464
# 6   2010  259   595   53   712    871  3770   435  256   49       7000
# 7   2011  280   502   66   396   1120  3008   865  141   40       6418
# 8   2012  305   523   27   269    757  1741   773  124   52       4571
# 9   2013  221   583   23   403   1139  2346   932  170   74       5891
# 10  2014  309   500   31   257   1075  1887   684  219   50       5012
# 11  2015  264   712   25   209   1601  2153  1030  156   57       6207
# ...

# %%
area_limpa = area_desmatada.drop('AMZ LEGAL', axis =1 )

# %%
fig2 = plt.line(data_frame=area_limpa,markers=True)
fig2.update_layout(title='Desmatamento por estado brasileiro. Quanto mais área o estado tem maior é o desmatamento.',xaxis_title = 'Ano (resumido)',yaxis_title='Área desmatada')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
